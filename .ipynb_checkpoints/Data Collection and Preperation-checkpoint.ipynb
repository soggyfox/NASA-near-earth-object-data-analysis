# %%
import json, requests, urllib
from pathlib import Path
from datetime import datetime
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import datetime

start_date = datetime.date(2020, 1, 27)
end_date = datetime.date(2020, 2, 25)

delta = datetime.timedelta(days=6)
date_list = []

while start_date + delta <= end_date:
    start_date += delta
    date_list.append(start_date.strftime('%Y-%m-%d'))


print(date_list)
# Out:
# ['2020-02-02', '2020-02-08', '2020-02-14', '2020-02-20']

# %%
api_key = 'Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'
empty_json = {}

for i in range(len(date_list)-1):
    start = date_list[i]
    end = date_list[i+1]
    endPoint = f'https://api.nasa.gov/neo/rest/v1/feed?start_date={start}&end_date={end}&api_key={api_key}'
    request = requests.get(endPoint)
    data = request.json()
    empty_json[start + '_' + end] = data
empty_json
# Out:
# {'2020-02-02_2020-02-08': {'links': {'next': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2020-02-08&end_date=2020-02-14&detailed=false&api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc',
#    'previous': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2020-01-27&end_date=2020-02-02&detailed=false&api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc',
#    'self': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2020-02-02&end_date=2020-02-08&detailed=false&api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#   'element_count': 134,
#   'near_earth_objects': {'2020-02-02': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2103067?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '2103067',
#      'neo_reference_id': '2103067',
#      'name': '103067 (1999 XA143)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2103067',
#      'absolute_magnitude_h': 16.84,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 1.1390819672,
#        'estimated_diameter_max': 2.5470647106},
#       'meters': {'estimated_diameter_min': 1139.0819672164,
#        'estimated_diameter_max': 2547.06471064},
#       'miles': {'estimated_diameter_min': 0.7077925011,
#        'estimated_diameter_max': 1.5826721463},
#       'feet': {'estimated_diameter_min': 3737.1456813222,
#        'estimated_diameter_max': 8356.5117852563}},
#      'is_potentially_hazardous_asteroid': True,
#      'close_approach_data': [{'close_approach_date': '2020-02-02',
#        'close_approach_date_full': '2020-Feb-02 23:35',
#        'epoch_date_close_approach': 1580686500000,
#        'relative_velocity': {'kilometers_per_second': '22.5189166797',
#         'kilometers_per_hour': '81068.1000468642',
#         'miles_per_hour': '50372.5647207863'},
#        'miss_distance': {'astronomical': '0.304551315',
#         'lunar': '118.470461535',
#         'kilometers': '45560228.02969905',
#         'miles': '28309812.95418489'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2416231?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '2416231',
#      'neo_reference_id': '2416231',
#      'name': '416231 (2003 AJ73)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2416231',
#      'absolute_magnitude_h': 18.67,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.4904050984,
#        'estimated_diameter_max': 1.0965791366},
#       'meters': {'estimated_diameter_min': 490.4050984179,
#        'estimated_diameter_max': 1096.5791365749},
#       'miles': {'estimated_diameter_min': 0.3047235064,
#        'estimated_diameter_max': 0.6813824747},
#       'feet': {'estimated_diameter_min': 1608.9406630934,
#        'estimated_diameter_max': 3597.7006944404}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-02',
#        'close_approach_date_full': '2020-Feb-02 16:16',
#        'epoch_date_close_approach': 1580660160000,
#        'relative_velocity': {'kilometers_per_second': '3.2899983716',
#         'kilometers_per_hour': '11843.9941379139',
#         'miles_per_hour': '7359.3973575277'},
#        'miss_distance': {'astronomical': '0.4825571865',
#         'lunar': '187.7147455485',
#         'kilometers': '72189527.253592755',
#         'miles': '44856492.212199819'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2503960?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '2503960',
#      'neo_reference_id': '2503960',
#      'name': '503960 (2004 QF1)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2503960',
#      'absolute_magnitude_h': 18.29,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.5841911542,
#        'estimated_diameter_max': 1.3062911326},
#       'meters': {'estimated_diameter_min': 584.1911541862,
#        'estimated_diameter_max': 1306.2911326144},
#       'miles': {'estimated_diameter_min': 0.3629994417,
#        'estimated_diameter_max': 0.8116914274},
#       'feet': {'estimated_diameter_min': 1916.6377063003,
#        'estimated_diameter_max': 4285.7321995267}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-02',
#        'close_approach_date_full': '2020-Feb-02 13:22',
#        'epoch_date_close_approach': 1580649720000,
#        'relative_velocity': {'kilometers_per_second': '13.7043955204',
#         'kilometers_per_hour': '49335.8238733234',
#         'miles_per_hour': '30655.3623395103'},
#        'miss_distance': {'astronomical': '0.252535737',
#         'lunar': '98.236401693',
#         'kilometers': '37778808.35408019',
#         'miles': '23474662.976639022'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2512245?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '2512245',
#      'neo_reference_id': '2512245',
#      'name': '512245 (2016 AU8)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2512245',
#      'absolute_magnitude_h': 19.8,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2914439045,
#        'estimated_diameter_max': 0.6516883822},
#       'meters': {'estimated_diameter_min': 291.4439045349,
#        'estimated_diameter_max': 651.6883821679},
#       'miles': {'estimated_diameter_min': 0.1810947904,
#        'estimated_diameter_max': 0.4049402617},
#       'feet': {'estimated_diameter_min': 956.1808197541,
#        'estimated_diameter_max': 2138.0853117517}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-02',
#        'close_approach_date_full': '2020-Feb-02 10:14',
#        'epoch_date_close_approach': 1580638440000,
#        'relative_velocity': {'kilometers_per_second': '7.0442338704',
#         'kilometers_per_hour': '25359.2419333055',
#         'miles_per_hour': '15757.2467446142'},
#        'miss_distance': {'astronomical': '0.1931581512',
#         'lunar': '75.1385208168',
#         'kilometers': '28896047.992657944',
#         'miles': '17955171.6302658672'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3421513?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '3421513',
#      'neo_reference_id': '3421513',
#      'name': '(2008 OX1)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3421513',
#      'absolute_magnitude_h': 21.5,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1332155667,
#        'estimated_diameter_max': 0.2978790628},
#       'meters': {'estimated_diameter_min': 133.2155666981,
#        'estimated_diameter_max': 297.8790627982},
#       'miles': {'estimated_diameter_min': 0.0827762899,
#        'estimated_diameter_max': 0.1850934111},
#       'feet': {'estimated_diameter_min': 437.0589598459,
#        'estimated_diameter_max': 977.2935443908}},
#      'is_potentially_hazardous_asteroid': True,
#      'close_approach_data': [{'close_approach_date': '2020-02-02',
#        'close_approach_date_full': '2020-Feb-02 22:54',
#        'epoch_date_close_approach': 1580684040000,
#        'relative_velocity': {'kilometers_per_second': '16.9822340509',
#         'kilometers_per_hour': '61136.0425834081',
#         'miles_per_hour': '37987.5593485627'},
#        'miss_distance': {'astronomical': '0.1627285975',
#         'lunar': '63.3014244275',
#         'kilometers': '24343851.574087325',
#         'miles': '15126567.939862085'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3703884?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '3703884',
#      'neo_reference_id': '3703884',
#      'name': '(2015 AP45)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3703884',
#      'absolute_magnitude_h': 20.9,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1756123185,
#        'estimated_diameter_max': 0.3926810818},
#       'meters': {'estimated_diameter_min': 175.6123184804,
#        'estimated_diameter_max': 392.6810818086},
#       'miles': {'estimated_diameter_min': 0.1091204019,
#        'estimated_diameter_max': 0.2440006365},
#       'feet': {'estimated_diameter_min': 576.1559189633,
#        'estimated_diameter_max': 1288.3238004408}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-02',
#        'close_approach_date_full': '2020-Feb-02 22:06',
#        'epoch_date_close_approach': 1580681160000,
#        'relative_velocity': {'kilometers_per_second': '10.0821184506',
#         'kilometers_per_hour': '36295.6264221676',
#         'miles_per_hour': '22552.6907621518'},
#        'miss_distance': {'astronomical': '0.4760489462',
#         'lunar': '185.1830400718',
#         'kilometers': '71215908.367264594',
#         'miles': '44251513.4894716372'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3789674?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '3789674',
#      'neo_reference_id': '3789674',
#      'name': '(2017 WD15)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3789674',
#      'absolute_magnitude_h': 24.4,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0350392641,
#        'estimated_diameter_max': 0.0783501764},
#       'meters': {'estimated_diameter_min': 35.0392641108,
#        'estimated_diameter_max': 78.3501764334},
#       'miles': {'estimated_diameter_min': 0.0217723826,
#        'estimated_diameter_max': 0.0486845275},
#       'feet': {'estimated_diameter_min': 114.9582192654,
#        'estimated_diameter_max': 257.0543928497}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-02',
#        'close_approach_date_full': '2020-Feb-02 06:33',
#        'epoch_date_close_approach': 1580625180000,
#        'relative_velocity': {'kilometers_per_second': '10.7907591691',
#         'kilometers_per_hour': '38846.7330086603',
#         'miles_per_hour': '24137.8491852978'},
#        'miss_distance': {'astronomical': '0.2066032717',
#         'lunar': '80.3686726913',
#         'kilometers': '30907409.381351279',
#         'miles': '19204973.6431104902'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3799826?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '3799826',
#      'neo_reference_id': '3799826',
#      'name': '(2018 ER1)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3799826',
#      'absolute_magnitude_h': 25.6,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0201629919,
#        'estimated_diameter_max': 0.0450858206},
#       'meters': {'estimated_diameter_min': 20.1629919443,
#        'estimated_diameter_max': 45.0858206172},
#       'miles': {'estimated_diameter_min': 0.0125286985,
#        'estimated_diameter_max': 0.0280150214},
#       'feet': {'estimated_diameter_min': 66.1515504905,
#        'estimated_diameter_max': 147.9193637137}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-02',
#        'close_approach_date_full': '2020-Feb-02 18:25',
#        'epoch_date_close_approach': 1580667900000,
#        'relative_velocity': {'kilometers_per_second': '3.4905832337',
#         'kilometers_per_hour': '12566.0996411948',
#         'miles_per_hour': '7808.0856353857'},
#        'miss_distance': {'astronomical': '0.1545233829',
#         'lunar': '60.1095959481',
#         'kilometers': '23116368.947034423',
#         'miles': '14363845.6033161174'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3883106?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '3883106',
#      'neo_reference_id': '3883106',
#      'name': '(2019 UD8)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3883106',
#      'absolute_magnitude_h': 23.16,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0620233153,
#        'estimated_diameter_max': 0.1386883492},
#       'meters': {'estimated_diameter_min': 62.0233152954,
#        'estimated_diameter_max': 138.6883491905},
#       'miles': {'estimated_diameter_min': 0.0385394894,
#        'estimated_diameter_max': 0.0861769182},
#       'feet': {'estimated_diameter_min': 203.4885737539,
#        'estimated_diameter_max': 455.0142835581}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-02',
#        'close_approach_date_full': '2020-Feb-02 07:18',
#        'epoch_date_close_approach': 1580627880000,
#        'relative_velocity': {'kilometers_per_second': '12.2015006454',
#         'kilometers_per_hour': '43925.4023232766',
#         'miles_per_hour': '27293.5367935937'},
#        'miss_distance': {'astronomical': '0.3175600659',
#         'lunar': '123.5308656351',
#         'kilometers': '47506309.455699633',
#         'miles': '29519051.8791476154'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3986738?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '3986738',
#      'neo_reference_id': '3986738',
#      'name': '(2020 BV)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3986738',
#      'absolute_magnitude_h': 22.5,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0840533402,
#        'estimated_diameter_max': 0.1879489824},
#       'meters': {'estimated_diameter_min': 84.0533402073,
#        'estimated_diameter_max': 187.9489824394},
#       'miles': {'estimated_diameter_min': 0.0522283081,
#        'estimated_diameter_max': 0.1167860472},
#       'feet': {'estimated_diameter_min': 275.7655606856,
#        'estimated_diameter_max': 616.6305395464}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-02',
#        'close_approach_date_full': '2020-Feb-02 17:52',
#        'epoch_date_close_approach': 1580665920000,
#        'relative_velocity': {'kilometers_per_second': '14.1512296931',
#         'kilometers_per_hour': '50944.4268952406',
#         'miles_per_hour': '31654.8857005455'},
#        'miss_distance': {'astronomical': '0.0613104621',
#         'lunar': '23.8497697569',
#         'kilometers': '9171914.538875727',
#         'miles': '5699163.4207379526'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3989158?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '3989158',
#      'neo_reference_id': '3989158',
#      'name': '(2020 BY6)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3989158',
#      'absolute_magnitude_h': 24.1,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.040230458,
#        'estimated_diameter_max': 0.0899580388},
#       'meters': {'estimated_diameter_min': 40.2304579834,
#        'estimated_diameter_max': 89.9580388169},
#       'miles': {'estimated_diameter_min': 0.0249980399,
#        'estimated_diameter_max': 0.0558973165},
#       'feet': {'estimated_diameter_min': 131.9896957704,
#        'estimated_diameter_max': 295.1379320721}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-02',
#        'close_approach_date_full': '2020-Feb-02 10:13',
#        'epoch_date_close_approach': 1580638380000,
#        'relative_velocity': {'kilometers_per_second': '9.4816118257',
#         'kilometers_per_hour': '34133.8025723417',
#         'miles_per_hour': '21209.4174927975'},
#        'miss_distance': {'astronomical': '0.0807008134',
#         'lunar': '31.3926164126',
#         'kilometers': '12072669.791907458',
#         'miles': '7501609.1544526004'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3989204?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '3989204',
#      'neo_reference_id': '3989204',
#      'name': '(2020 BD9)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3989204',
#      'absolute_magnitude_h': 24.9,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0278326768,
#        'estimated_diameter_max': 0.0622357573},
#       'meters': {'estimated_diameter_min': 27.8326768072,
#        'estimated_diameter_max': 62.2357573367},
#       'miles': {'estimated_diameter_min': 0.0172944182,
#        'estimated_diameter_max': 0.0386714948},
#       'feet': {'estimated_diameter_min': 91.3145593761,
#        'estimated_diameter_max': 204.1855621004}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-02',
#        'close_approach_date_full': '2020-Feb-02 22:55',
#        'epoch_date_close_approach': 1580684100000,
#        'relative_velocity': {'kilometers_per_second': '7.5725135534',
#         'kilometers_per_hour': '27261.0487924133',
#         'miles_per_hour': '16938.9555677081'},
#        'miss_distance': {'astronomical': '0.0420549077',
#         'lunar': '16.3593590953',
#         'kilometers': '6291324.614966599',
#         'miles': '3909247.8415091062'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3989211?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '3989211',
#      'neo_reference_id': '3989211',
#      'name': '(2020 BL9)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3989211',
#      'absolute_magnitude_h': 22.8,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0732073989,
#        'estimated_diameter_max': 0.1636967205},
#       'meters': {'estimated_diameter_min': 73.2073989347,
#        'estimated_diameter_max': 163.696720474},
#       'miles': {'estimated_diameter_min': 0.0454889547,
#        'estimated_diameter_max': 0.1017163949},
#       'feet': {'estimated_diameter_min': 240.181762721,
#        'estimated_diameter_max': 537.0627483999}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-02',
#        'close_approach_date_full': '2020-Feb-02 20:42',
#        'epoch_date_close_approach': 1580676120000,
#        'relative_velocity': {'kilometers_per_second': '14.1583986489',
#         'kilometers_per_hour': '50970.2351360868',
#         'miles_per_hour': '31670.9219377535'},
#        'miss_distance': {'astronomical': '0.213332964',
#         'lunar': '82.986522996',
#         'kilometers': '31914157.01518668',
#         'miles': '19830537.614988984'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3989289?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '3989289',
#      'neo_reference_id': '3989289',
#      'name': '(2020 BB13)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3989289',
#      'absolute_magnitude_h': 22.7,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0766575574,
#        'estimated_diameter_max': 0.1714115092},
#       'meters': {'estimated_diameter_min': 76.6575573531,
#        'estimated_diameter_max': 171.4115092306},
#       'miles': {'estimated_diameter_min': 0.0476327831,
#        'estimated_diameter_max': 0.1065101409},
#       'feet': {'estimated_diameter_min': 251.5011804664,
#        'estimated_diameter_max': 562.3737359442}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-02',
#        'close_approach_date_full': '2020-Feb-02 06:58',
#        'epoch_date_close_approach': 1580626680000,
#        'relative_velocity': {'kilometers_per_second': '14.2231711013',
#         'kilometers_per_hour': '51203.4159647747',
#         'miles_per_hour': '31815.8114365568'},
#        'miss_distance': {'astronomical': '0.3002892191',
#         'lunar': '116.8125062299',
#         'kilometers': '44922627.561323317',
#         'miles': '27913626.3945510946'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3989358?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '3989358',
#      'neo_reference_id': '3989358',
#      'name': '(2020 BM15)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3989358',
#      'absolute_magnitude_h': 24.6,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0319561887,
#        'estimated_diameter_max': 0.0714562102},
#       'meters': {'estimated_diameter_min': 31.9561886721,
#        'estimated_diameter_max': 71.4562101727},
#       'miles': {'estimated_diameter_min': 0.0198566489,
#        'estimated_diameter_max': 0.0444008168},
#       'feet': {'estimated_diameter_min': 104.8431420431,
#        'estimated_diameter_max': 234.436392583}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-02',
#        'close_approach_date_full': '2020-Feb-02 19:10',
#        'epoch_date_close_approach': 1580670600000,
#        'relative_velocity': {'kilometers_per_second': '12.5087377571',
#         'kilometers_per_hour': '45031.4559255899',
#         'miles_per_hour': '27980.7954888756'},
#        'miss_distance': {'astronomical': '0.1240911234',
#         'lunar': '48.2714470026',
#         'kilometers': '18563767.746547158',
#         'miles': '11534990.3930924604'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3989349?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '3989349',
#      'neo_reference_id': '3989349',
#      'name': '(2020 CA)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3989349',
#      'absolute_magnitude_h': 29.6,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0031956189,
#        'estimated_diameter_max': 0.007145621},
#       'meters': {'estimated_diameter_min': 3.1956188672,
#        'estimated_diameter_max': 7.1456210173},
#       'miles': {'estimated_diameter_min': 0.0019856649,
#        'estimated_diameter_max': 0.0044400817},
#       'feet': {'estimated_diameter_min': 10.4843142043,
#        'estimated_diameter_max': 23.4436392583}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-02',
#        'close_approach_date_full': '2020-Feb-02 15:49',
#        'epoch_date_close_approach': 1580658540000,
#        'relative_velocity': {'kilometers_per_second': '13.2600419467',
#         'kilometers_per_hour': '47736.1510081837',
#         'miles_per_hour': '29661.3878306128'},
#        'miss_distance': {'astronomical': '0.0014655653',
#         'lunar': '0.5701049017',
#         'kilometers': '219245.447225911',
#         'miles': '136232.8037071318'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3991555?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '3991555',
#      'neo_reference_id': '3991555',
#      'name': '(2020 CC2)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3991555',
#      'absolute_magnitude_h': 25.09,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0255008688,
#        'estimated_diameter_max': 0.0570216761},
#       'meters': {'estimated_diameter_min': 25.5008687857,
#        'estimated_diameter_max': 57.0216760901},
#       'miles': {'estimated_diameter_min': 0.0158455003,
#        'estimated_diameter_max': 0.0354316159},
#       'feet': {'estimated_diameter_min': 83.6642703469,
#        'estimated_diameter_max': 187.0789957835}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-02',
#        'close_approach_date_full': '2020-Feb-02 08:35',
#        'epoch_date_close_approach': 1580632500000,
#        'relative_velocity': {'kilometers_per_second': '11.2901435525',
#         'kilometers_per_hour': '40644.5167891148',
#         'miles_per_hour': '25254.9221126586'},
#        'miss_distance': {'astronomical': '0.0629922901',
#         'lunar': '24.5040008489',
#         'kilometers': '9423512.425382087',
#         'miles': '5855499.0980313206'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3991666?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '3991666',
#      'neo_reference_id': '3991666',
#      'name': '(2020 DO1)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3991666',
#      'absolute_magnitude_h': 25.48,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0213086029,
#        'estimated_diameter_max': 0.0476474846},
#       'meters': {'estimated_diameter_min': 21.3086029248,
#        'estimated_diameter_max': 47.6474846455},
#       'miles': {'estimated_diameter_min': 0.0132405479,
#        'estimated_diameter_max': 0.0296067652},
#       'feet': {'estimated_diameter_min': 69.9101168199,
#        'estimated_diameter_max': 156.3237735244}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-02',
#        'close_approach_date_full': '2020-Feb-02 09:44',
#        'epoch_date_close_approach': 1580636640000,
#        'relative_velocity': {'kilometers_per_second': '6.4953789544',
#         'kilometers_per_hour': '23383.3642358739',
#         'miles_per_hour': '14529.5131831184'},
#        'miss_distance': {'astronomical': '0.0370490568',
#         'lunar': '14.4120830952',
#         'kilometers': '5542459.982789016',
#         'miles': '3443924.9363837808'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54117577?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '54117577',
#      'neo_reference_id': '54117577',
#      'name': '(2021 CC7)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54117577',
#      'absolute_magnitude_h': 29.74,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0029960908,
#        'estimated_diameter_max': 0.0066994628},
#       'meters': {'estimated_diameter_min': 2.9960908385,
#        'estimated_diameter_max': 6.6994627817},
#       'miles': {'estimated_diameter_min': 0.001861684,
#        'estimated_diameter_max': 0.0041628519},
#       'feet': {'estimated_diameter_min': 9.8296946666,
#        'estimated_diameter_max': 21.9798654727}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-02',
#        'close_approach_date_full': '2020-Feb-02 23:47',
#        'epoch_date_close_approach': 1580687220000,
#        'relative_velocity': {'kilometers_per_second': '9.3838597969',
#         'kilometers_per_hour': '33781.8952689445',
#         'miles_per_hour': '20990.7559797505'},
#        'miss_distance': {'astronomical': '0.2540984952',
#         'lunar': '98.8443146328',
#         'kilometers': '38012593.652125224',
#         'miles': '23619930.4247031312'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54144233?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '54144233',
#      'neo_reference_id': '54144233',
#      'name': '(2021 JQ2)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54144233',
#      'absolute_magnitude_h': 30.01,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0026457876,
#        'estimated_diameter_max': 0.0059161609},
#       'meters': {'estimated_diameter_min': 2.6457875993,
#        'estimated_diameter_max': 5.9161609261},
#       'miles': {'estimated_diameter_min': 0.0016440157,
#        'estimated_diameter_max': 0.0036761308},
#       'feet': {'estimated_diameter_min': 8.6804057874,
#        'estimated_diameter_max': 19.4099774128}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-02',
#        'close_approach_date_full': '2020-Feb-02 02:55',
#        'epoch_date_close_approach': 1580612100000,
#        'relative_velocity': {'kilometers_per_second': '19.3909860169',
#         'kilometers_per_hour': '69807.5496607993',
#         'miles_per_hour': '43375.6966211783'},
#        'miss_distance': {'astronomical': '0.4173347424',
#         'lunar': '162.3432147936',
#         'kilometers': '62432388.540038688',
#         'miles': '38793687.3515943744'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54239783?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '54239783',
#      'neo_reference_id': '54239783',
#      'name': '(2022 BS)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54239783',
#      'absolute_magnitude_h': 23.93,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0435065831,
#        'estimated_diameter_max': 0.0972836774},
#       'meters': {'estimated_diameter_min': 43.5065831396,
#        'estimated_diameter_max': 97.2836773688},
#       'miles': {'estimated_diameter_min': 0.0270337291,
#        'estimated_diameter_max': 0.0604492559},
#       'feet': {'estimated_diameter_min': 142.7381382276,
#        'estimated_diameter_max': 319.1721800586}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-02',
#        'close_approach_date_full': '2020-Feb-02 07:36',
#        'epoch_date_close_approach': 1580628960000,
#        'relative_velocity': {'kilometers_per_second': '19.9949877803',
#         'kilometers_per_hour': '71981.9560091048',
#         'miles_per_hour': '44726.7881657685'},
#        'miss_distance': {'astronomical': '0.1756083927',
#         'lunar': '68.3116647603',
#         'kilometers': '26270641.502043549',
#         'miles': '16323819.6837930162'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54304124?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '54304124',
#      'neo_reference_id': '54304124',
#      'name': '(2022 SD)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54304124',
#      'absolute_magnitude_h': 25.83,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0181365625,
#        'estimated_diameter_max': 0.0405545866},
#       'meters': {'estimated_diameter_min': 18.1365624903,
#        'estimated_diameter_max': 40.5545866065},
#       'miles': {'estimated_diameter_min': 0.011269534,
#        'estimated_diameter_max': 0.025199444},
#       'feet': {'estimated_diameter_min': 59.5031596806,
#        'estimated_diameter_max': 133.0531099219}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-02',
#        'close_approach_date_full': '2020-Feb-02 00:16',
#        'epoch_date_close_approach': 1580602560000,
#        'relative_velocity': {'kilometers_per_second': '8.4606549373',
#         'kilometers_per_hour': '30458.3577743922',
#         'miles_per_hour': '18925.6390293161'},
#        'miss_distance': {'astronomical': '0.429186724',
#         'lunar': '166.953635636',
#         'kilometers': '64205419.74267788',
#         'miles': '39895397.853919544'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54331176?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '54331176',
#      'neo_reference_id': '54331176',
#      'name': '(2022 WY11)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54331176',
#      'absolute_magnitude_h': 22.57,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0813869881,
#        'estimated_diameter_max': 0.1819868378},
#       'meters': {'estimated_diameter_min': 81.3869880675,
#        'estimated_diameter_max': 181.9868378029},
#       'miles': {'estimated_diameter_min': 0.0505715142,
#        'estimated_diameter_max': 0.1130813434},
#       'feet': {'estimated_diameter_min': 267.0176859314,
#        'estimated_diameter_max': 597.0696969372}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-02',
#        'close_approach_date_full': '2020-Feb-02 23:34',
#        'epoch_date_close_approach': 1580686440000,
#        'relative_velocity': {'kilometers_per_second': '6.4656557136',
#         'kilometers_per_hour': '23276.360569052',
#         'miles_per_hour': '14463.025265809'},
#        'miss_distance': {'astronomical': '0.44503759',
#         'lunar': '173.11962251',
#         'kilometers': '66576675.5339333',
#         'miles': '41368827.87874754'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False}],
#    '2020-02-03': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2350523?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '2350523',
#      'neo_reference_id': '2350523',
#      'name': '350523 (2000 EA14)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2350523',
#      'absolute_magnitude_h': 21.16,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1557955241,
#        'estimated_diameter_max': 0.3483693825},
#       'meters': {'estimated_diameter_min': 155.7955241278,
#        'estimated_diameter_max': 348.36938254},
#       'miles': {'estimated_diameter_min': 0.0968068206,
#        'estimated_diameter_max': 0.2164666316},
#       'feet': {'estimated_diameter_min': 511.1401873795,
#        'estimated_diameter_max': 1142.9442050126}},
#      'is_potentially_hazardous_asteroid': True,
#      'close_approach_data': [{'close_approach_date': '2020-02-03',
#        'close_approach_date_full': '2020-Feb-03 14:46',
#        'epoch_date_close_approach': 1580741160000,
#        'relative_velocity': {'kilometers_per_second': '14.9123168116',
#         'kilometers_per_hour': '53684.3405218619',
#         'miles_per_hour': '33357.3614759313'},
#        'miss_distance': {'astronomical': '0.324509137',
#         'lunar': '126.234054293',
#         'kilometers': '48545875.69073819',
#         'miles': '30165008.384199422'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2525364?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '2525364',
#      'neo_reference_id': '2525364',
#      'name': '525364 (2005 CL7)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2525364',
#      'absolute_magnitude_h': 19.63,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3151773333,
#        'estimated_diameter_max': 0.7047579421},
#       'meters': {'estimated_diameter_min': 315.1773332628,
#        'estimated_diameter_max': 704.7579421428},
#       'miles': {'estimated_diameter_min': 0.1958420547,
#        'estimated_diameter_max': 0.4379161473},
#       'feet': {'estimated_diameter_min': 1034.046402062,
#        'estimated_diameter_max': 2312.1980468998}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-03',
#        'close_approach_date_full': '2020-Feb-03 02:58',
#        'epoch_date_close_approach': 1580698680000,
#        'relative_velocity': {'kilometers_per_second': '16.0409042004',
#         'kilometers_per_hour': '57747.255121552',
#         'miles_per_hour': '35881.8986059443'},
#        'miss_distance': {'astronomical': '0.1875484988',
#         'lunar': '72.9563660332',
#         'kilometers': '28056855.942177556',
#         'miles': '17433721.8700440328'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3631993?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '3631993',
#      'neo_reference_id': '3631993',
#      'name': '(2013 ES41)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3631993',
#      'absolute_magnitude_h': 26.6,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0127219879,
#        'estimated_diameter_max': 0.0284472297},
#       'meters': {'estimated_diameter_min': 12.7219878539,
#        'estimated_diameter_max': 28.4472296503},
#       'miles': {'estimated_diameter_min': 0.0079050743,
#        'estimated_diameter_max': 0.0176762835},
#       'feet': {'estimated_diameter_min': 41.7388066307,
#        'estimated_diameter_max': 93.330808926}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-03',
#        'close_approach_date_full': '2020-Feb-03 11:42',
#        'epoch_date_close_approach': 1580730120000,
#        'relative_velocity': {'kilometers_per_second': '10.9925260618',
#         'kilometers_per_hour': '39573.0938223115',
#         'miles_per_hour': '24589.1815475357'},
#        'miss_distance': {'astronomical': '0.1426733421',
#         'lunar': '55.4999300769',
#         'kilometers': '21343628.083941327',
#         'miles': '13262315.5096192326'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3704148?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '3704148',
#      'neo_reference_id': '3704148',
#      'name': '(2015 BY3)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3704148',
#      'absolute_magnitude_h': 27.5,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.008405334,
#        'estimated_diameter_max': 0.0187948982},
#       'meters': {'estimated_diameter_min': 8.4053340207,
#        'estimated_diameter_max': 18.7948982439},
#       'miles': {'estimated_diameter_min': 0.0052228308,
#        'estimated_diameter_max': 0.0116786047},
#       'feet': {'estimated_diameter_min': 27.5765560686,
#        'estimated_diameter_max': 61.6630539546}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-03',
#        'close_approach_date_full': '2020-Feb-03 12:15',
#        'epoch_date_close_approach': 1580732100000,
#        'relative_velocity': {'kilometers_per_second': '30.2740017457',
#         'kilometers_per_hour': '108986.4062846392',
#         'miles_per_hour': '67719.9145050304'},
#        'miss_distance': {'astronomical': '0.4492468189',
#         'lunar': '174.7570125521',
#         'kilometers': '67206367.211715743',
#         'miles': '41760100.1437855334'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3767013?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '3767013',
#      'neo_reference_id': '3767013',
#      'name': '(2017 BY6)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3767013',
#      'absolute_magnitude_h': 26.0,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0167708462,
#        'estimated_diameter_max': 0.0375007522},
#       'meters': {'estimated_diameter_min': 16.7708462163,
#        'estimated_diameter_max': 37.5007521798},
#       'miles': {'estimated_diameter_min': 0.0104209175,
#        'estimated_diameter_max': 0.0233018799},
#       'feet': {'estimated_diameter_min': 55.0224631002,
#        'estimated_diameter_max': 123.0339677816}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-03',
#        'close_approach_date_full': '2020-Feb-03 07:13',
#        'epoch_date_close_approach': 1580713980000,
#        'relative_velocity': {'kilometers_per_second': '15.2092818629',
#         'kilometers_per_hour': '54753.4147063734',
#         'miles_per_hour': '34021.6425990796'},
#        'miss_distance': {'astronomical': '0.272896436',
#         'lunar': '106.156713604',
#         'kilometers': '40824725.55619132',
#         'miles': '25367308.162907416'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3767163?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '3767163',
#      'neo_reference_id': '3767163',
#      'name': '(2017 BP30)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3767163',
#      'absolute_magnitude_h': 26.0,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0167708462,
#        'estimated_diameter_max': 0.0375007522},
#       'meters': {'estimated_diameter_min': 16.7708462163,
#        'estimated_diameter_max': 37.5007521798},
#       'miles': {'estimated_diameter_min': 0.0104209175,
#        'estimated_diameter_max': 0.0233018799},
#       'feet': {'estimated_diameter_min': 55.0224631002,
#        'estimated_diameter_max': 123.0339677816}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-03',
#        'close_approach_date_full': '2020-Feb-03 03:09',
#        'epoch_date_close_approach': 1580699340000,
#        'relative_velocity': {'kilometers_per_second': '9.2417757457',
#         'kilometers_per_hour': '33270.3926843755',
#         'miles_per_hour': '20672.9281654666'},
#        'miss_distance': {'astronomical': '0.0875265939',
#         'lunar': '34.0478450271',
#         'kilometers': '13093792.015794993',
#         'miles': '8136105.0824091834'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3797752?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '3797752',
#      'neo_reference_id': '3797752',
#      'name': '(2018 BU1)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3797752',
#      'absolute_magnitude_h': 24.6,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0319561887,
#        'estimated_diameter_max': 0.0714562102},
#       'meters': {'estimated_diameter_min': 31.9561886721,
#        'estimated_diameter_max': 71.4562101727},
#       'miles': {'estimated_diameter_min': 0.0198566489,
#        'estimated_diameter_max': 0.0444008168},
#       'feet': {'estimated_diameter_min': 104.8431420431,
#        'estimated_diameter_max': 234.436392583}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-03',
#        'close_approach_date_full': '2020-Feb-03 23:41',
#        'epoch_date_close_approach': 1580773260000,
#        'relative_velocity': {'kilometers_per_second': '9.8127456897',
#         'kilometers_per_hour': '35325.884482755',
#         'miles_per_hour': '21950.1308331874'},
#        'miss_distance': {'astronomical': '0.0576104399',
#         'lunar': '22.4104611211',
#         'kilometers': '8618399.098803013',
#         'miles': '5355224.8749190594'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3825598?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '3825598',
#      'neo_reference_id': '3825598',
#      'name': '(2018 NF2)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3825598',
#      'absolute_magnitude_h': 22.8,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0732073989,
#        'estimated_diameter_max': 0.1636967205},
#       'meters': {'estimated_diameter_min': 73.2073989347,
#        'estimated_diameter_max': 163.696720474},
#       'miles': {'estimated_diameter_min': 0.0454889547,
#        'estimated_diameter_max': 0.1017163949},
#       'feet': {'estimated_diameter_min': 240.181762721,
#        'estimated_diameter_max': 537.0627483999}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-03',
#        'close_approach_date_full': '2020-Feb-03 04:31',
#        'epoch_date_close_approach': 1580704260000,
#        'relative_velocity': {'kilometers_per_second': '16.6681856631',
#         'kilometers_per_hour': '60005.4683871308',
#         'miles_per_hour': '37285.0645097703'},
#        'miss_distance': {'astronomical': '0.2690281817',
#         'lunar': '104.6519626813',
#         'kilometers': '40246042.952292979',
#         'miles': '25007731.4666379502'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3856714?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '3856714',
#      'neo_reference_id': '3856714',
#      'name': '(2019 SM4)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3856714',
#      'absolute_magnitude_h': 23.5,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0530340723,
#        'estimated_diameter_max': 0.1185877909},
#       'meters': {'estimated_diameter_min': 53.0340723319,
#        'estimated_diameter_max': 118.5877908577},
#       'miles': {'estimated_diameter_min': 0.0329538346,
#        'estimated_diameter_max': 0.0736870142},
#       'feet': {'estimated_diameter_min': 173.9963058693,
#        'estimated_diameter_max': 389.0675677576}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-03',
#        'close_approach_date_full': '2020-Feb-03 10:57',
#        'epoch_date_close_approach': 1580727420000,
#        'relative_velocity': {'kilometers_per_second': '7.0032733126',
#         'kilometers_per_hour': '25211.7839253975',
#         'miles_per_hour': '15665.6220729782'},
#        'miss_distance': {'astronomical': '0.4960674464',
#         'lunar': '192.9702366496',
#         'kilometers': '74210633.357779168',
#         'miles': '46112349.3104737984'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3888752?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '3888752',
#      'neo_reference_id': '3888752',
#      'name': '(2019 UK12)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3888752',
#      'absolute_magnitude_h': 25.8,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0183888672,
#        'estimated_diameter_max': 0.0411187571},
#       'meters': {'estimated_diameter_min': 18.388867207,
#        'estimated_diameter_max': 41.1187571041},
#       'miles': {'estimated_diameter_min': 0.0114263088,
#        'estimated_diameter_max': 0.0255500032},
#       'feet': {'estimated_diameter_min': 60.3309310875,
#        'estimated_diameter_max': 134.9040630575}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-03',
#        'close_approach_date_full': '2020-Feb-03 15:36',
#        'epoch_date_close_approach': 1580744160000,
#        'relative_velocity': {'kilometers_per_second': '2.8023905554',
#         'kilometers_per_hour': '10088.6059993657',
#         'miles_per_hour': '6268.6674333281'},
#        'miss_distance': {'astronomical': '0.1528879826',
#         'lunar': '59.4734252314',
#         'kilometers': '22871716.545557062',
#         'miles': '14211825.6502969756'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3893852?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '3893852',
#      'neo_reference_id': '3893852',
#      'name': '(2019 XG)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3893852',
#      'absolute_magnitude_h': 21.86,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1128638801,
#        'estimated_diameter_max': 0.2523713081},
#       'meters': {'estimated_diameter_min': 112.8638800969,
#        'estimated_diameter_max': 252.3713081011},
#       'miles': {'estimated_diameter_min': 0.070130342,
#        'estimated_diameter_max': 0.1568162121},
#       'feet': {'estimated_diameter_min': 370.2883323772,
#        'estimated_diameter_max': 827.9898824705}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-03',
#        'close_approach_date_full': '2020-Feb-03 09:11',
#        'epoch_date_close_approach': 1580721060000,
#        'relative_velocity': {'kilometers_per_second': '2.8774106244',
#         'kilometers_per_hour': '10358.678247709',
#         'miles_per_hour': '6436.479825639'},
#        'miss_distance': {'astronomical': '0.2046294925',
#         'lunar': '79.6008725825',
#         'kilometers': '30612136.217180975',
#         'miles': '19021499.406708455'},
# ...
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-19',
#        'close_approach_date_full': '2020-Feb-19 20:36',
#        'epoch_date_close_approach': 1582144560000,
#        'relative_velocity': {'kilometers_per_second': '15.3495385181',
#         'kilometers_per_hour': '55258.338665048',
#         'miles_per_hour': '34335.3827110683'},
#        'miss_distance': {'astronomical': '0.0099197038',
#         'lunar': '3.8587647782',
#         'kilometers': '1483966.559510906',
#         'miles': '922094.0620102628'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3991595?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '3991595',
#      'neo_reference_id': '3991595',
#      'name': '(2020 CU2)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3991595',
#      'absolute_magnitude_h': 27.3,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0092162655,
#        'estimated_diameter_max': 0.0206081961},
#       'meters': {'estimated_diameter_min': 9.216265485,
#        'estimated_diameter_max': 20.6081961232},
#       'miles': {'estimated_diameter_min': 0.0057267201,
#        'estimated_diameter_max': 0.0128053354},
#       'feet': {'estimated_diameter_min': 30.2370924539,
#        'estimated_diameter_max': 67.6121941689}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-19',
#        'close_approach_date_full': '2020-Feb-19 23:47',
#        'epoch_date_close_approach': 1582156020000,
#        'relative_velocity': {'kilometers_per_second': '8.2677465143',
#         'kilometers_per_hour': '29763.8874516247',
#         'miles_per_hour': '18494.1221779276'},
#        'miss_distance': {'astronomical': '0.0337771579',
#         'lunar': '13.1393144231',
#         'kilometers': '5052990.876493673',
#         'miles': '3139782.9369837674'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3991592?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '3991592',
#      'neo_reference_id': '3991592',
#      'name': '(2020 DA)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3991592',
#      'absolute_magnitude_h': 24.5,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0334622374,
#        'estimated_diameter_max': 0.0748238376},
#       'meters': {'estimated_diameter_min': 33.4622374455,
#        'estimated_diameter_max': 74.8238376074},
#       'miles': {'estimated_diameter_min': 0.0207924639,
#        'estimated_diameter_max': 0.0464933628},
#       'feet': {'estimated_diameter_min': 109.7842471007,
#        'estimated_diameter_max': 245.4850393757}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-19',
#        'close_approach_date_full': '2020-Feb-19 11:37',
#        'epoch_date_close_approach': 1582112220000,
#        'relative_velocity': {'kilometers_per_second': '10.3682586483',
#         'kilometers_per_hour': '37325.7311338724',
#         'miles_per_hour': '23192.7577703776'},
#        'miss_distance': {'astronomical': '0.0202188981',
#         'lunar': '7.8651513609',
#         'kilometers': '3024704.089507047',
#         'miles': '1879463.9693173686'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3991618?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '3991618',
#      'neo_reference_id': '3991618',
#      'name': '(2020 DN)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3991618',
#      'absolute_magnitude_h': 23.9,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.04411182,
#        'estimated_diameter_max': 0.0986370281},
#       'meters': {'estimated_diameter_min': 44.1118199997,
#        'estimated_diameter_max': 98.6370281305},
#       'miles': {'estimated_diameter_min': 0.0274098057,
#        'estimated_diameter_max': 0.0612901888},
#       'feet': {'estimated_diameter_min': 144.7238235278,
#        'estimated_diameter_max': 323.6123073718}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-19',
#        'close_approach_date_full': '2020-Feb-19 03:42',
#        'epoch_date_close_approach': 1582083720000,
#        'relative_velocity': {'kilometers_per_second': '18.1531793179',
#         'kilometers_per_hour': '65351.4455443939',
#         'miles_per_hour': '40606.8468161819'},
#        'miss_distance': {'astronomical': '0.1772804414',
#         'lunar': '68.9620917046',
#         'kilometers': '26520776.426099818',
#         'miles': '16479246.3183727684'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3991730?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '3991730',
#      'neo_reference_id': '3991730',
#      'name': '(2020 DD2)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3991730',
#      'absolute_magnitude_h': 25.9,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0175612318,
#        'estimated_diameter_max': 0.0392681082},
#       'meters': {'estimated_diameter_min': 17.561231848,
#        'estimated_diameter_max': 39.2681081809},
#       'miles': {'estimated_diameter_min': 0.0109120402,
#        'estimated_diameter_max': 0.0244000636},
#       'feet': {'estimated_diameter_min': 57.6155918963,
#        'estimated_diameter_max': 128.8323800441}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-19',
#        'close_approach_date_full': '2020-Feb-19 05:53',
#        'epoch_date_close_approach': 1582091580000,
#        'relative_velocity': {'kilometers_per_second': '10.1887420335',
#         'kilometers_per_hour': '36679.4713204279',
#         'miles_per_hour': '22791.1970546292'},
#        'miss_distance': {'astronomical': '0.009972474',
#         'lunar': '3.879292386',
#         'kilometers': '1491860.86903038',
#         'miles': '926999.358484044'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3991735?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '3991735',
#      'neo_reference_id': '3991735',
#      'name': '(2020 DJ2)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3991735',
#      'absolute_magnitude_h': 26.3,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0146067964,
#        'estimated_diameter_max': 0.0326617897},
#       'meters': {'estimated_diameter_min': 14.6067964271,
#        'estimated_diameter_max': 32.6617897446},
#       'miles': {'estimated_diameter_min': 0.0090762397,
#        'estimated_diameter_max': 0.020295089},
#       'feet': {'estimated_diameter_min': 47.92256199,
#        'estimated_diameter_max': 107.1581062656}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-19',
#        'close_approach_date_full': '2020-Feb-19 05:16',
#        'epoch_date_close_approach': 1582089360000,
#        'relative_velocity': {'kilometers_per_second': '11.8220892526',
#         'kilometers_per_hour': '42559.5213095134',
#         'miles_per_hour': '26444.8314492362'},
#        'miss_distance': {'astronomical': '0.0072206613',
#         'lunar': '2.8088372457',
#         'kilometers': '1080195.550471431',
#         'miles': '671202.3909945078'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54005708?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '54005708',
#      'neo_reference_id': '54005708',
#      'name': '(2020 DG4)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54005708',
#      'absolute_magnitude_h': 28.2,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0060891262,
#        'estimated_diameter_max': 0.0136157002},
#       'meters': {'estimated_diameter_min': 6.0891262211,
#        'estimated_diameter_max': 13.6157001539},
#       'miles': {'estimated_diameter_min': 0.0037836064,
#        'estimated_diameter_max': 0.0084604012},
#       'feet': {'estimated_diameter_min': 19.9774488711,
#        'estimated_diameter_max': 44.6709336928}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-19',
#        'close_approach_date_full': '2020-Feb-19 23:56',
#        'epoch_date_close_approach': 1582156560000,
#        'relative_velocity': {'kilometers_per_second': '7.1776484368',
#         'kilometers_per_hour': '25839.5343726589',
#         'miles_per_hour': '16055.6817883891'},
#        'miss_distance': {'astronomical': '0.0084802135',
#         'lunar': '3.2988030515',
#         'kilometers': '1268621.876745245',
#         'miles': '788285.080944581'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54006019?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '54006019',
#      'neo_reference_id': '54006019',
#      'name': '(2020 DN4)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54006019',
#      'absolute_magnitude_h': 27.9,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0069912523,
#        'estimated_diameter_max': 0.0156329154},
#       'meters': {'estimated_diameter_min': 6.9912523225,
#        'estimated_diameter_max': 15.6329154409},
#       'miles': {'estimated_diameter_min': 0.0043441614,
#        'estimated_diameter_max': 0.0097138403},
#       'feet': {'estimated_diameter_min': 22.9371802696,
#        'estimated_diameter_max': 51.289094295}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-19',
#        'close_approach_date_full': '2020-Feb-19 00:35',
#        'epoch_date_close_approach': 1582072500000,
#        'relative_velocity': {'kilometers_per_second': '6.1729653636',
#         'kilometers_per_hour': '22222.67530907',
#         'miles_per_hour': '13808.3062219052'},
#        'miss_distance': {'astronomical': '0.0121110182',
#         'lunar': '4.7111860798',
#         'kilometers': '1811782.526251234',
#         'miles': '1125789.4582616692'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54016358?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '54016358',
#      'neo_reference_id': '54016358',
#      'name': '(2020 FN4)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54016358',
#      'absolute_magnitude_h': 24.5,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0334622374,
#        'estimated_diameter_max': 0.0748238376},
#       'meters': {'estimated_diameter_min': 33.4622374455,
#        'estimated_diameter_max': 74.8238376074},
#       'miles': {'estimated_diameter_min': 0.0207924639,
#        'estimated_diameter_max': 0.0464933628},
#       'feet': {'estimated_diameter_min': 109.7842471007,
#        'estimated_diameter_max': 245.4850393757}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-19',
#        'close_approach_date_full': '2020-Feb-19 04:43',
#        'epoch_date_close_approach': 1582087380000,
#        'relative_velocity': {'kilometers_per_second': '6.7742339127',
#         'kilometers_per_hour': '24387.2420855495',
#         'miles_per_hour': '15153.2838392127'},
#        'miss_distance': {'astronomical': '0.0686972993',
#         'lunar': '26.7232494277',
#         'kilometers': '10276969.650032491',
#         'miles': '6385812.8264547358'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54111250?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '54111250',
#      'neo_reference_id': '54111250',
#      'name': '(2021 CN3)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54111250',
#      'absolute_magnitude_h': 26.23,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0150853356,
#        'estimated_diameter_max': 0.0337318359},
#       'meters': {'estimated_diameter_min': 15.0853356118,
#        'estimated_diameter_max': 33.7318358913},
#       'miles': {'estimated_diameter_min': 0.0093735901,
#        'estimated_diameter_max': 0.0209599846},
#       'feet': {'estimated_diameter_min': 49.4925724885,
#        'estimated_diameter_max': 110.6687564656}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-19',
#        'close_approach_date_full': '2020-Feb-19 01:34',
#        'epoch_date_close_approach': 1582076040000,
#        'relative_velocity': {'kilometers_per_second': '14.8255878868',
#         'kilometers_per_hour': '53372.1163924577',
#         'miles_per_hour': '33163.3575439691'},
#        'miss_distance': {'astronomical': '0.4051081803',
#         'lunar': '157.5870821367',
#         'kilometers': '60603320.892455961',
#         'miles': '37657157.4169798218'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2549948?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '2549948',
#      'neo_reference_id': '2549948',
#      'name': '549948 (2011 WL2)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2549948',
#      'absolute_magnitude_h': 20.84,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1805323255,
#        'estimated_diameter_max': 0.4036825521},
#       'meters': {'estimated_diameter_min': 180.5323255496,
#        'estimated_diameter_max': 403.6825520651},
#       'miles': {'estimated_diameter_min': 0.1121775517,
#        'estimated_diameter_max': 0.2508366311},
#       'feet': {'estimated_diameter_min': 592.2976749563,
#        'estimated_diameter_max': 1324.4178641174}},
#      'is_potentially_hazardous_asteroid': True,
#      'close_approach_data': [{'close_approach_date': '2020-02-19',
#        'close_approach_date_full': '2020-Feb-19 03:04',
#        'epoch_date_close_approach': 1582081440000,
#        'relative_velocity': {'kilometers_per_second': '8.4833049623',
#         'kilometers_per_hour': '30539.8978642234',
#         'miles_per_hour': '18976.3048701337'},
#        'miss_distance': {'astronomical': '0.4593402296',
#         'lunar': '178.6833493144',
#         'kilometers': '68716319.953470952',
#         'miles': '42698341.2706930576'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False},
#     {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54301286?api_key=Zy0KEjh7yatP1bj69QAGsbuXjCAuEAgiTacrtvCc'},
#      'id': '54301286',
#      'neo_reference_id': '54301286',
#      'name': '(2022 RG1)',
#      'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54301286',
#      'absolute_magnitude_h': 26.39,
#      'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0140137697,
#        'estimated_diameter_max': 0.0313357417},
#       'meters': {'estimated_diameter_min': 14.0137697166,
#        'estimated_diameter_max': 31.3357417074},
#       'miles': {'estimated_diameter_min': 0.0087077501,
#        'estimated_diameter_max': 0.0194711212},
#       'feet': {'estimated_diameter_min': 45.9769362371,
#        'estimated_diameter_max': 102.8075548233}},
#      'is_potentially_hazardous_asteroid': False,
#      'close_approach_data': [{'close_approach_date': '2020-02-19',
#        'close_approach_date_full': '2020-Feb-19 11:05',
#        'epoch_date_close_approach': 1582110300000,
#        'relative_velocity': {'kilometers_per_second': '13.3647757477',
#         'kilometers_per_hour': '48113.1926918352',
#         'miles_per_hour': '29895.6668701017'},
#        'miss_distance': {'astronomical': '0.0941906974',
#         'lunar': '36.6401812886',
#         'kilometers': '14090727.704854538',
#         'miles': '8755572.1945191044'},
#        'orbiting_body': 'Earth'}],
#      'is_sentry_object': False}]}}}

# %%
import pyperclip as clip


empty_json
clip.copy(f"{empty_json}")

# %%
import copy

total = {
    "element_count": 0,
    "near_earth_objects": {}
}

for period in empty_json:
    for date in empty_json[period]["near_earth_objects"]:
        if date not in total["near_earth_objects"]:
            total["near_earth_objects"][date] = copy.deepcopy(empty_json[period]["near_earth_objects"][date])
        else:
            total["near_earth_objects"][date].extend(empty_json[period]["near_earth_objects"][date])
        total["element_count"] += empty_json[period]["element_count"]

output = {"total": total}

# %%
clip.copy(f"{output}")

# %%
print('h')
# Out:
# h

# %%
# Out:
# h
